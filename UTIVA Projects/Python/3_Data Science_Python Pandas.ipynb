# %% [markdown]
# ### Pandas

# %%
#IMPORTING PANDAS

#!pip install numpy 
import pandas as pd


#Data structures in Pandas:
    #Series
    #DataFrames

# %% [markdown]
# #### Creating Data Structures

# %%
#CREATING A SERIES
fruits = pd.Series(["Apple", "Orange", "Banana", "Strawberries"])
print(fruits)
# Out:
# 0           Apple
# 1          Orange
# 2          Banana
# 3    Strawberries
# dtype: object

# %%
#CREATING A DATAFRAME
#1. with code

m_data = {
    "Name": ["Damilare", "John", "Fred"], 
    "Age": [25, 23, 28],
    "City": ["Lagos", "Dublin", "London"]
}

m_df = pd.DataFrame(m_data)
print(m_df)
# Out:
#        Name  Age    City
# 0  Damilare   25   Lagos
# 1      John   23  Dublin
# 2      Fred   28  London

# %% [markdown]
# #### Reading in Files in Pandas

# %%
#to import files of different formats

#to import a CSV file
#Syntax: variablename = pd.read.fileformat(r"filepath", sep = "separator")

m_df_csv = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\countries of the world.csv")

#r before filepath to prevent error message
#sep may not be defined when the file contain comma separated data

print(m_df_csv)
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
#to import files of different formats

#to import a JSON file
#Syntax: variablename = pd.read.fileformat(r"filepath")

m_df_json = pd.read_json(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\json_sample.json")

#r before filepath to prevent error message
#sep may not be defined when the file contain comma separated data

print(m_df_json)
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
#to import files of different formats

#to import a EXCEL file
#Syntax: variablename = pd.read.fileformat(r"filepath", sheet_name = "sheetname")

m_df_excel = pd.read_excel(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\world_population_excel_workbook.xlsx", sheet_name = "Sheet1")

#r before filepath to prevent error message
#sep may not be defined when the file contain comma separated data

print(m_df_excel)
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %% [markdown]
# #### Looking at Data in the DataFrame

# %%
#import a CSV file
m_df = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\world_population.csv")


print(m_df)
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
#to display the first few rows in the DataFrame: HEAD FUNCTION

#displays the first 5 rows when you do not specify.
m_df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
#to display the first few rows in the DataFrame: HEAD FUNCTION

#displays the specified rows.
m_df.head(2)
# Out:
#    Rank CCA3      Country Capital Continent  2022 Population  2020 Population  \
# 0    36  AFG  Afghanistan   Kabul      Asia       41128771.0       38972230.0
# 1   138  ALB      Albania  Tirana    Europe        2842321.0        2866849.0
#
#    2015 Population  2010 Population  2000 Population  1990 Population  \
# 0       33753499.0       28189672.0       19542982.0       10694796.0
# 1        2882481.0        2913399.0        3182021.0        3295066.0
#
#    1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 0       12486631.0       10752971.0    652230.0            63.0587
# 1        2941651.0        2324731.0     28748.0            98.8702
#
#    Growth Rate  World Population Percentage
# 0       1.0257                         0.52
# 1       0.9957                         0.04

# %%
#to display the last few rows in the DataFrame: TAIL FUNCTION

#displays the last 5 rows when you do not specify.
m_df.tail()
# Out:
#      Rank CCA3            Country   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania          11572.0
# 230   172  ESH     Western Sahara  El Aaiún    Africa         575986.0
# 231    46  YEM              Yemen     Sanaa      Asia       33696614.0
# 232    63  ZMB             Zambia    Lusaka    Africa       20017675.0
# 233    74  ZWE           Zimbabwe    Harare    Africa       16320537.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229          11655.0          12182.0          13142.0          14723.0
# 230         556048.0         491824.0         413296.0         270375.0
# 231       32284046.0       28516545.0       24743946.0       18628700.0
# 232       18927715.0              NaN       13792086.0        9891136.0
# 233       15669666.0       14154937.0       12839771.0       11834676.0
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
#to display the first few rows in the DataFrame: HEAD FUNCTION

#displays the specified rows.
m_df.tail(4)
# Out:
#      Rank CCA3         Country   Capital Continent  2022 Population  \
# 230   172  ESH  Western Sahara  El Aaiún    Africa         575986.0
# 231    46  YEM           Yemen     Sanaa      Asia       33696614.0
# 232    63  ZMB          Zambia    Lusaka    Africa       20017675.0
# 233    74  ZWE        Zimbabwe    Harare    Africa       16320537.0
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 230         556048.0         491824.0         413296.0         270375.0
# 231       32284046.0       28516545.0       24743946.0       18628700.0
# 232       18927715.0              NaN       13792086.0        9891136.0
# 233       15669666.0       14154937.0       12839771.0       11834676.0
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 230         178529.0         116775.0          76371.0    266000.0
# 231       13375121.0        9204938.0        6843607.0    527968.0
# ...

# %%
#to determine the shape (dimension) of the dataframe: SHAPE

#for dimension
m_df.shape
# Out:
# (234, 17)

# %%
#for some basic information about the dataframe: INFO FUNCTION

#for basic info
m_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
#for some basic statistics of numerical columns: DESCRIBE FUNCTION

#for basic statistics
m_df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.300000e+02     2.330000e+02     2.300000e+02
# mean   117.500000     3.463225e+07     3.360071e+07     3.206600e+07
# std     67.694165     1.378892e+08     1.358732e+08     1.315071e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.064710e+05     3.942950e+05
# 50%    117.500000     5.762857e+06     5.456681e+06     5.244415e+06
# 75%    175.750000     2.265372e+07     2.152263e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.270000e+02     2.270000e+02     2.290000e+02     2.290000e+02
# mean      3.027016e+07     2.684050e+07     1.933046e+07     1.628288e+07
# std       1.260742e+08     1.133525e+08     8.130962e+07     6.934547e+07
# ...

# %% [markdown]
# #### Accessing, Filtering and Sorting Data in Pandas

# %% [markdown]
# ##### Accessing Data in Pandas

# %%
#Accessing one column in the DataFrame

m_df["Country"].head()
# Out:
# 0       Afghanistan
# 1           Albania
# 2           Algeria
# 3    American Samoa
# 4           Andorra
# Name: Country, dtype: object

# %%
#Accessing more than one column in the DataFrame

m_df[["Country","Capital", "2022 Population"]].head()
# Out:
#           Country           Capital  2022 Population
# 0     Afghanistan             Kabul       41128771.0
# 1         Albania            Tirana        2842321.0
# 2         Algeria           Algiers       44903225.0
# 3  American Samoa         Pago Pago          44273.0
# 4         Andorra  Andorra la Vella          79824.0

# %% [markdown]
# ##### Filtering Data in Pandas

# %%
#to get specific Data

#z.B: where continent is Asia

m_dfAsia = m_df[m_df["Continent"] == "Asia"]
print(m_dfAsia.shape)
print()
print(m_dfAsia)
# Out:
# (50, 17)
#
#      Rank CCA3               Country              Capital Continent  \
# 0      36  AFG           Afghanistan                Kabul      Asia
# 9     140  ARM               Armenia              Yerevan      Asia
# 13     91  AZE            Azerbaijan                 Baku      Asia
# 15    154  BHR               Bahrain               Manama      Asia
# 16      8  BGD            Bangladesh                Dhaka      Asia
# 23    165  BTN                Bhutan              Thimphu      Asia
# 29    175  BRN                Brunei  Bandar Seri Begawan      Asia
# 33     73  KHM              Cambodia           Phnom Penh      Asia
# 41      1  CHN                 China              Beijing      Asia
# 73    131  GEO               Georgia              Tbilisi      Asia
# 89    104  HKG             Hong Kong            Hong Kong      Asia
# 92      2  IND                 India            New Delhi      Asia
# 93      4  IDN             Indonesia              Jakarta      Asia
# ...

# %%
#to get specific Data

#z.B: where continent is Africa

m_dfAfrica = m_df[m_df["Continent"] == "Africa"]
print(m_dfAfrica.shape)
print()
print(m_dfAfrica)
# Out:
# (57, 17)
#
#      Rank CCA3                   Country       Capital Continent  \
# 2      34  DZA                   Algeria       Algiers    Africa
# 5      42  AGO                    Angola        Luanda    Africa
# 21     77  BEN                     Benin    Porto-Novo    Africa
# 26    144  BWA                  Botswana      Gaborone    Africa
# 31     58  BFA              Burkina Faso   Ouagadougou    Africa
# 32     78  BDI                   Burundi     Bujumbura    Africa
# 34     53  CMR                  Cameroon       Yaounde    Africa
# 36    171  CPV                Cape Verde         Praia    Africa
# 38    117  CAF  Central African Republic        Bangui    Africa
# 39     69  TCD                      Chad     N'Djamena    Africa
# 43    163  COM                   Comoros        Moroni    Africa
# 52    160  DJI                  Djibouti      Djibouti    Africa
# 55     15  COD                  DR Congo      Kinshasa    Africa
# ...

# %%
#to get specific Data

#z.B: where population is greater than 200M

m_dflargPop = m_df[m_df["2022 Population"] > 200000000]
print(m_dflargPop.shape)
print()
print(m_dflargPop)
# Out:
# (7, 17)
#
#      Rank CCA3        Country           Capital      Continent  \
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# 93      2.755013e+08     2.718580e+08     2.590920e+08     2.440162e+08
# 149     2.185412e+08     2.083274e+08     1.839958e+08     1.609529e+08
# ...

# %% [markdown]
# ##### Sorting Data in Pandas

# %%
#Sorting: in a specific order

#z.B: where continent is Africa

m_dfAfrica.sort_values(by = "2022 Population")

#this sorts by 2022 Population in ascending order
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 185   196  SYC                Seychelles      Victoria    Africa
# 181   187  STP     Sao Tome and Principe      São Tomé    Africa
# 130   182  MYT                   Mayotte     Mamoudzou    Africa
# 230   172  ESH            Western Sahara      El Aaiún    Africa
# 36    171  CPV                Cape Verde         Praia    Africa
# 43    163  COM                   Comoros        Moroni    Africa
# 169   161  REU                   Reunion   Saint-Denis    Africa
# 52    160  DJI                  Djibouti      Djibouti    Africa
# 129   157  MUS                 Mauritius    Port Louis    Africa
# 59    152  GNQ         Equatorial Guinea        Malabo    Africa
# 85    149  GNB             Guinea-Bissau        Bissau    Africa
# 113   147  LSO                   Lesotho        Maseru    Africa
# 71    146  GAB                     Gabon    Libreville    Africa
# ...

# %%
#Sorting: in a specific order

#z.B: where continent is Africa

m_dfAfrica.sort_values(by = "2022 Population", ascending = False)

#this sorts by 2022 Population in descending order
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 149     6  NGA                   Nigeria         Abuja    Africa
# 63     12  ETH                  Ethiopia   Addis Ababa    Africa
# 57     14  EGY                     Egypt         Cairo    Africa
# 55     15  COD                  DR Congo      Kinshasa    Africa
# 205    22  TZA                  Tanzania        Dodoma    Africa
# 193    24  ZAF              South Africa      Pretoria    Africa
# 106    27  KEN                     Kenya       Nairobi    Africa
# 217    31  UGA                    Uganda       Kampala    Africa
# 198    32  SDN                     Sudan      Khartoum    Africa
# 2      34  DZA                   Algeria       Algiers    Africa
# 138    40  MAR                   Morocco         Rabat    Africa
# 5      42  AGO                    Angola        Luanda    Africa
# 75     47  GHA                     Ghana         Accra    Africa
# ...

# %%
#Sorting: in a specific order
#multiple columns
#z.B: where continent is Africa

m_dfAfrica.sort_values(by = ["Rank", "2022 Population"])

#this sorts by multiple columns (similar to SQL) in ascending order
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 149     6  NGA                   Nigeria         Abuja    Africa
# 63     12  ETH                  Ethiopia   Addis Ababa    Africa
# 57     14  EGY                     Egypt         Cairo    Africa
# 55     15  COD                  DR Congo      Kinshasa    Africa
# 205    22  TZA                  Tanzania        Dodoma    Africa
# 193    24  ZAF              South Africa      Pretoria    Africa
# 106    27  KEN                     Kenya       Nairobi    Africa
# 217    31  UGA                    Uganda       Kampala    Africa
# 198    32  SDN                     Sudan      Khartoum    Africa
# 2      34  DZA                   Algeria       Algiers    Africa
# 138    40  MAR                   Morocco         Rabat    Africa
# 5      42  AGO                    Angola        Luanda    Africa
# 75     47  GHA                     Ghana         Accra    Africa
# ...

# %% [markdown]
# #### Indexing, Loc and Iloc in Pandas

# %%
#Changing DataFrame Index

#z.B to change the default index from numbers to country

#m_df.head()

#new index: country
m_df.set_index("Country")

#NB: this change is not store to memory
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
#Changing DataFrame Index

#z.B to change the default index from numbers to country



#new index: country
m_df.set_index("Country",inplace = True)

#NB: with 'Inplace', this change is stored to memory

# %%
#to check the changes

m_df.head()
# Out:
#                 Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan       36  AFG             Kabul      Asia       41128771.0
# Albania          138  ALB            Tirana    Europe        2842321.0
# Algeria           34  DZA           Algiers    Africa       44903225.0
# American Samoa   213  ASM         Pago Pago   Oceania          44273.0
# Andorra          203  AND  Andorra la Vella    Europe          79824.0
#
#                 2020 Population  2015 Population  2010 Population  \
# Country
# Afghanistan          38972230.0       33753499.0       28189672.0
# Albania               2866849.0        2882481.0        2913399.0
# Algeria              43451666.0       39543154.0       35856344.0
# American Samoa          46189.0          51368.0          54849.0
# Andorra                 77700.0          71746.0          71519.0
#
#                 2000 Population  1990 Population  1980 Population  \
# Country
# ...

# %%
#to search rows and columns using labels: LOC

m_df.loc["Nigeria"]

#it returns all the rows and columns of the specified label
# Out:
# Rank                                     6
# CCA3                                   NGA
# Capital                              Abuja
# Continent                           Africa
# 2022 Population                218541212.0
# 2020 Population                208327405.0
# 2015 Population                183995785.0
# 2010 Population                160952853.0
# 2000 Population                122851984.0
# 1990 Population                 95214257.0
# 1980 Population                 72951439.0
# 1970 Population                 55569264.0
# Area (km²)                        923768.0
# Density (per km²)                 236.5759
# Growth Rate                         1.0241
# World Population Percentage           2.74
# Name: Nigeria, dtype: object

# %%
#to search rows and columns using labels: LOC

m_df.loc["Germany"]

#it returns all the rows and columns of the specified label
# Out:
# Rank                                   19
# CCA3                                  DEU
# Capital                            Berlin
# Continent                          Europe
# 2022 Population                83369843.0
# 2020 Population                83328988.0
# 2015 Population                82073226.0
# 2010 Population                81325090.0
# 2000 Population                81551677.0
# 1990 Population                79370196.0
# 1980 Population                77786703.0
# 1970 Population                78294583.0
# Area (km²)                       357114.0
# Density (per km²)                233.4544
# Growth Rate                        0.9995
# World Population Percentage          1.05
# Name: Germany, dtype: object

# %%
#to search rows and columns using integer-based index: ILOC

m_df.iloc[0]

#it returns all the rows and columns of the specified index
#'NB: Country name not shown since we changed it to index
#to change back to default index
# Out:
# Rank                                   36
# CCA3                                  AFG
# Capital                             Kabul
# Continent                            Asia
# 2022 Population                41128771.0
# 2020 Population                38972230.0
# 2015 Population                33753499.0
# 2010 Population                28189672.0
# 2000 Population                19542982.0
# 1990 Population                10694796.0
# 1980 Population                12486631.0
# 1970 Population                10752971.0
# Area (km²)                       652230.0
# Density (per km²)                 63.0587
# Growth Rate                        1.0257
# World Population Percentage          0.52
# Name: Afghanistan, dtype: object

# %%
#to search rows and columns using integer-based index: ILOC

#to change back to default index
m_df.reset_index(inplace = True)

#rerun
m_df.iloc[0]

#it returns all the rows and columns of the specified index
#'NB: Country name now shown
# Out:
# Country                        Afghanistan
# Rank                                    36
# CCA3                                   AFG
# Capital                              Kabul
# Continent                             Asia
# 2022 Population                 41128771.0
# 2020 Population                 38972230.0
# 2015 Population                 33753499.0
# 2010 Population                 28189672.0
# 2000 Population                 19542982.0
# 1990 Population                 10694796.0
# 1980 Population                 12486631.0
# 1970 Population                 10752971.0
# Area (km²)                        652230.0
# Density (per km²)                  63.0587
# Growth Rate                         1.0257
# World Population Percentage           0.52
# Name: 0, dtype: object

# %% [markdown]
# #### Groupby and Aggregate functions in Pandas

# %%
#import sample dataset
m_flav = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\Flavors.csv")

m_flav.head()
# Out:
#                 Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0  Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1            Chocolate   Chocolate   Yes            8.8             7.6
# 2              Vanilla     Vanilla    No            4.7             5.0
# 3         Cookie Dough     Vanilla   Yes            6.9             6.5
# 4           Rocky Road   Chocolate   Yes            8.2             7.0
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2

# %%
m_flavgb = m_flav.groupby("Base Flavor")

m_flavgb.head()
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 8          15.3

# %%
## Aggregation:Mean
#Syntax: variable_name = variable_name.groupby(column_name).mean()

m_flavgb = m_flav.groupby("Base Flavor")
m_flavgb.mean(numeric_only = True)
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
## Aggregation:Mean
#Alternative Syntax: variable_name = variable_name.groupby(column_name).mean()

m_flav.groupby("Base Flavor").mean(numeric_only = True)
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
## Aggregation:Sum
#Syntax: variable_name = variable_name.groupby(column_name).sum()

m_flav.groupby("Base Flavor").sum(numeric_only = True)

#or

#m_flavgb = m_flav.groupby("Base Flavor")
#m_flavgb.sum(numeric_only = True)
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate             25.2            21.7          47.1
# Vanilla               34.2            33.9          68.1

# %%
## Aggregation 
#for multiple aggregation to one or more columns: AGG FUNCTION

#agg function

m_flav.groupby("Base Flavor").agg({ 
    "Flavor Rating": ["mean", "min", "max", "count"]  
})
# Out:
#             Flavor Rating
#                      mean  min   max count
# Base Flavor
# Chocolate             8.4  8.2   8.8     3
# Vanilla               5.7  2.3  10.0     6

# %%
## Aggregation 
#for multiple aggregation to one or more columns: AGG FUNCTION

#agg function

m_flav.groupby("Base Flavor").agg({ 
    "Flavor Rating": ["mean", "min", "max", "count"],
    "Texture Rating": ["mean", "min", "max", "count"]
})
# Out:
#             Flavor Rating                  Texture Rating
#                      mean  min   max count           mean  min  max count
# Base Flavor
# Chocolate             8.4  8.2   8.8     3       7.233333  7.0  7.6     3
# Vanilla               5.7  2.3  10.0     6       5.650000  3.4  8.0     6

# %%
## grouping and Aggregation 
#grouping by more than one column and multiple aggregation to one or more columns: AGG FUNCTION

#agg function

m_flav.groupby(["Base Flavor", "Liked"]).agg({ 
    "Flavor Rating": ["mean", "min", "max", "count"],
    "Texture Rating": ["mean", "min", "max", "count"]
})
# Out:
#                   Flavor Rating                  Texture Rating            \
#                            mean  min   max count           mean  min  max
# Base Flavor Liked
# Chocolate   Yes             8.4  8.2   8.8     3       7.233333  7.0  7.6
# Vanilla     No              3.6  2.3   4.7     3       4.466667  3.4  5.0
#             Yes             7.8  6.5  10.0     3       6.833333  6.0  8.0
#
#
#                   count
# Base Flavor Liked
# Chocolate   Yes       3
# Vanilla     No        3
#             Yes       3

# %% [markdown]
# #### Merge, Join, and Concatenate in Pandas

# %%
#MERGE

#merging allows to combine two or more DataFrames based on common columns or indices

#Syntax: pd.merge(left, right, how = "inner", on = None, left_on = None, right_on = None)

# %%
#Merging z.B

#import both files
m_LOTR1 = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\LOTR.csv")

m_LOTR2 = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\LOTR 2.csv")

# %%
#check file 1
m_LOTR1
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
#check file 2
m_LOTR2
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
#MERGE and JOIN
#to merge both files

#inner
m_LOTR1.merge(m_LOTR2, how = "inner", on = "FellowshipID")

#name column is repeated
# Out:
#    FellowshipID FirstName_x     Skills FirstName_y  Age
# 0          1001       Frodo     Hiding       Frodo   50
# 1          1002     Samwise  Gardening     Samwise   39

# %%
#MERGE
#to merge both files

#inner
m_LOTR1.merge(m_LOTR2, how = "inner", on = ["FellowshipID", "FirstName"])


#name column not repeated
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
#MERGE
#to merge both files

#outer

m_LOTR1.merge(m_LOTR2, how = "outer", on = ["FellowshipID", "FirstName"])
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
#MERGE
#to merge both files

#left

m_LOTR1.merge(m_LOTR2, how = "left", on = ["FellowshipID", "FirstName"])
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding  50.0
# 1          1002   Samwise  Gardening  39.0
# 2          1003   Gandalf     Spells   NaN
# 3          1004    Pippin  Fireworks   NaN

# %%
#MERGE
#to merge both files

#right

m_LOTR1.merge(m_LOTR2, how = "right", on = ["FellowshipID", "FirstName"])
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding    50
# 1          1002   Samwise  Gardening    39
# 2          1006   Legolas        NaN  2931
# 3          1007    Elrond        NaN  6520
# 4          1008  Barromir        NaN    51

# %%
#JOIN
#to combine DataFrames using their indices

#inner

#m_LOTR1.join(m_LOTR2, on = "FellowshipID", how = "outer", lsuffix = "l", rsuffix = "r")

#this is not really right because indices were nbot matching(better when the fellowshipID is changed to index)

# %%
#JOIN
#change DataFrame indiced to FellowshipID

m_LOTR1b = m_LOTR1.set_index("FellowshipID")
m_LOTR2b = m_LOTR2.set_index("FellowshipID")

# %%
#JOIN
#to combine DataFrames using their indices

#outer join
m_LOTR1b.join(m_LOTR2b, how = "outer", lsuffix = "l", rsuffix = "r")
# Out:
#              FirstNamel     Skills FirstNamer     Age
# FellowshipID
# 1001              Frodo     Hiding      Frodo    50.0
# 1002            Samwise  Gardening    Samwise    39.0
# 1003            Gandalf     Spells        NaN     NaN
# 1004             Pippin  Fireworks        NaN     NaN
# 1006                NaN        NaN    Legolas  2931.0
# 1007                NaN        NaN     Elrond  6520.0
# 1008                NaN        NaN   Barromir    51.0

# %%
#JOIN
#to combine DataFrames using their indices

#inner join
m_LOTR1b.join(m_LOTR2b, how = "inner", lsuffix = "l", rsuffix = "r")
# Out:
#              FirstNamel     Skills FirstNamer  Age
# FellowshipID
# 1001              Frodo     Hiding      Frodo   50
# 1002            Samwise  Gardening    Samwise   39

# %%
#CONCATENATE
#to put together

#APPEND function
pd.concat([m_LOTR1, m_LOTR2])

#or
#m_LOTR_concat = pd.concat([m_LOTR1, m_LOTR2])
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0

# %% [markdown]
# #### Data Cleaning in Pandas

# %%
#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories.csv")
print (m_cal.shape)
print()
m_cal
# Out:
# (32, 5)
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#CLEANING

#removing Nulls using DROPNA

m_cal.dropna(inplace = True)
print (m_cal.shape)
print()
m_cal.head()
# Out:
# (29, 5)
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories.csv")
print (m_cal.shape)
print()
m_cal.head()
# Out:
# (32, 5)
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
#CLEANING

#replacing the empty values

#check where null is present in the sample data
m_cal.info() 
#result shows null is present in columns: date and calories
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
#or - check where null is present in the sample data
m_cal.isna()

#result is in form of True(where null is present) or False
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
#or - check where null is present in the sample data
m_cal.isna().sum()
#result shows the total nulls per column
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
#CLEANING

#replacing the empty values using FILLNA 

#replacing with a random value
#m_cal["Calories"].fillna(130, inplace = True)     #old method #to be changed in future versions of pandas

#df.method({col: value}, inplace=True)              #update method
#df[col] = df[col].method(value)                    # or update method

#m_cal.fillna({"Calories": 130}, inplace=True) 


m_cal["Calories"] = m_cal["Calories"].fillna(130) 

#quick overview
m_cal.isna().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories.csv")
print (m_cal.shape)
print()
m_cal.head()
# Out:
# (32, 5)
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
#find the mean value

m_calm = m_cal["Calories"].mean()
m_calm
# Out:
# 304.68

# %%
#CLEANING

#replacing the empty values using FILLNA 

#replacing with the mean value
#m_cal["Calories"].fillna(m_calm, inplace = True)     #old method #to be changed in future versions of pandas

m_cal["Calories"] = m_cal["Calories"].fillna(m_calm) 

#quick overview
m_cal.isna().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories.csv")
print (m_cal.shape)
print()
m_cal.head()
print()
#find the median value

m_calmd = m_cal["Calories"].median()
print(m_calmd)
print()
#replacing with the median value
#m_cal["Calories"].fillna(m_calmd, inplace = True)     #old method #to be changed in future versions of pandas

m_cal["Calories"] = m_cal["Calories"].fillna(m_calmd)

#quick overview
m_cal.isna().sum()
# Out:
# (32, 5)
#
#
# 291.2
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
#CLEANING

#treating wrong data format

#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories.csv")
print (m_cal.shape)
m_cal.info()
#result shows date datatype as object
# Out:
# (32, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
#to convert to datetime format
#m_cal["Date"] = pd.to_datetime(m_cal["Date"])
m_cal["Date"] = pd.to_datetime(m_cal["Date"], format='%d/%m/%Y', errors='coerce')
m_cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      0 non-null      datetime64[ns]
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.4 KB

# %%
#CLEANING

#treating wrong data/input

#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories.csv")
print (m_cal.shape)
m_cal.head(10)
#result shows index(7) as 450 instead of 45
# Out:
# (32, 5)
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# 5        60  '2020/12/06'    102       127     300.0
# 6        60  '2020/12/07'    110       136     374.0
# 7       450  '2020/12/08'    104       134     253.3
# 8        30  '2020/12/09'    109       133     195.1
# 9        60  '2020/12/10'     98       124     269.0

# %%
#to correct wrong data

m_cal.loc[7, "Duration"] = 45
m_cal.head(10)
#result shows index(7) duration as 45
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# 5        60  '2020/12/06'    102       127     300.0
# 6        60  '2020/12/07'    110       136     374.0
# 7        45  '2020/12/08'    104       134     253.3
# 8        30  '2020/12/09'    109       133     195.1
# 9        60  '2020/12/10'     98       124     269.0

# %%
#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories.csv")
print (m_cal.shape)
m_cal.head(10)
#result shows index(7) as 450 instead of 45
# Out:
# (32, 5)
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# 5        60  '2020/12/06'    102       127     300.0
# 6        60  '2020/12/07'    110       136     374.0
# 7       450  '2020/12/08'    104       134     253.3
# 8        30  '2020/12/09'    109       133     195.1
# 9        60  '2020/12/10'     98       124     269.0

# %%
#z.B - in large dataset, a function can be written

#loop through each index in the DataFrame, when you see a cell in the Duration column where the value is greater than 100,
#replace that value with 90

for i in m_cal.index:
    if m_cal.loc[i, "Duration"] > 100:
        m_cal.loc[i, "Duration"] = 90

m_cal.head(10)
#result shows index(7) duration as 90
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# 5        60  '2020/12/06'    102       127     300.0
# 6        60  '2020/12/07'    110       136     374.0
# 7        90  '2020/12/08'    104       134     253.3
# 8        30  '2020/12/09'    109       133     195.1
# 9        60  '2020/12/10'     98       124     269.0

# %%
#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories.csv")
print (m_cal.shape)
m_cal.head(10)
# Out:
# (32, 5)
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# 5        60  '2020/12/06'    102       127     300.0
# 6        60  '2020/12/07'    110       136     374.0
# 7       450  '2020/12/08'    104       134     253.3
# 8        30  '2020/12/09'    109       133     195.1
# 9        60  '2020/12/10'     98       124     269.0

# %%
#you can also drop the row 
for i in m_cal.index:
    if m_cal.loc[i, "Duration"] > 100:
        m_cal.drop(i, inplace = True)
m_cal.head(10)
#result shows index(7) dropped
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3

# %%
#CLEANING

#treating duplicates

#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories.csv")
print (m_cal.shape)
#m_cal.head(15)
m_cal.iloc[10:15]

#result shows indices (11 and 12) are duplicates since they contain matching values
# Out:
# (32, 5)
#     Duration          Date  Pulse  Maxpulse  Calories
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3

# %%
#check for duplicates

#m_cal.duplicated() 
#result shows true for duplicates

#or
m_cal.duplicated().sum()
# Out:
# 1

# %%
#to drop duplicates - DROP_DUPLICATES


m_cal.drop_duplicates(inplace = True)

m_cal.duplicated().sum()
#result shows no duplicates
# Out:
# 0

# %% [markdown]
# #### Data Visualization in Pandas

# %%
#import sample file
m_cal = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\calories_corrected.csv")
print (m_cal.shape)
m_cal.head(10)
m_cal.info()
# Out:
# (32, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
##1. dropping null values
m_cal.dropna(inplace = True)
#m_cal.isna().sum()

##2. correct wrong data
m_cal.loc[7, "Duration"] = 45
#m_cal.head(10)
#result shows index(7) duration as 45

##3.convert wrong date format to datetime format

#to verify column names
#print(m_cal.columns)

#to 
#print(m_cal['Date'].head())
#m_cal['Date'] = pd.to_datetime(m_cal['Date'], format='%d/%m/%Y', errors='coerce')         #geht nicht mehr!
m_cal['Date'] = pd.to_datetime(m_cal['Date'],format='mixed', errors='coerce')
#m_cal.info()


##4. change index to date column
# Check if 'Date' exists and has no missing values
if "Date" in m_cal.columns and m_cal["Date"].isna().sum() == 0:
    m_cal.set_index("Date", inplace=True)
    print(m_cal.head())
else:
    print("Error: The 'Date' column is missing or contains NaN values.")


#m_cal.head(10)
#m_cal.tail(10)
m_cal.sample(10)
#m_cal.info()
# Out:
#             Duration  Pulse  Maxpulse  Calories
# Date
# 2020-12-01        60    110       130     409.1
# 2020-12-02        60    117       145     479.0
# 2020-12-03        60    103       135     340.0
# 2020-12-04        45    109       175     282.4
# 2020-12-05        45    117       148     406.0
#             Duration  Pulse  Maxpulse  Calories
# Date
# 2020-12-08        45    104       134     253.3
# 2020-12-23        60    130       101     300.0
# 2020-12-15        60     98       123     275.0
# 2020-12-06        60    102       127     300.0
# 2020-12-01        60    110       130     409.1
# 2020-12-26        60    100       120     250.0
# 2020-12-16        60     98       120     215.2
# 2020-12-25        60    102       126     334.5
# 2020-12-05        45    117       148     406.0
# 2020-12-14        60    104       132     379.3

# %%
#Visualization overview
m_cal.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Visualization overview

#for duration
m_cal["Duration"].plot()

#for calories
m_cal["Calories"].plot(
    title = "Plot of daily calories", ylabel = "Calories", rot = 45);

# %%
#Visualization overview

#for duration
m_cal["Duration"].plot()

#for all
m_cal.plot(
    title = "Plots", ylabel = "Calories", rot = 45,
subplots = True)
# Out:
# array([<Axes: xlabel='Date', ylabel='Calories'>,
#        <Axes: xlabel='Date', ylabel='Calories'>,
#        <Axes: xlabel='Date', ylabel='Calories'>,
#        <Axes: xlabel='Date', ylabel='Calories'>], dtype=object)

# %%
#Visualization overview

#for duration
#m_cal["Duration"].plot()

#for calories
m_cal.plot(
    title = "Plots of Daily Fitness checks", 
    #ylabel = "Calories", 
    rot = 45,
subplots = True, 
    figsize = (20, 7))                         #length:20 and width:7
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
#Visualization overview

#for duration
m_cal["Duration"].plot()

#for calories
m_cal.plot(
    #kind = default = line plot
    title = "Plots", 
    #ylabel = "Calories", 
    rot = 45,
    subplots = True, 
    figsize = (20, 7),
    layout = (2, 2)
);

# %%
#Visualization overview

#for duration
#m_cal["Duration"].plot()

#for calories
m_cal.plot(
    kind = "bar",
    title = "Plots", 
    #ylabel = "Calories", 
    rot = 45,
    subplots = True, 
    figsize = (20, 7)
);

# %%
#Visualization overview

#for duration
#m_cal["Duration"].plot()

#for calories
m_cal.plot(
    kind = "bar",
    title = "Plots", 
    #ylabel = "Calories", 
    rot = 45,
    subplots = True, 
    figsize = (20, 7),
    layout = (2, 2)
);

# %%
#Visualization overview

#for duration
#m_cal["Duration"].plot()

#for calories
m_cal.plot(
    kind = "barh",
    title = "Plots", 
    #ylabel = "Calories", 
    rot = 45,
    subplots = True, 
    figsize = (20, 7),
    layout = (2, 2)
);

# %%
#Visualization overview

#for duration
#m_cal["Duration"].plot()

#for calories
m_cal.plot(
    kind = "hist",
    title = "Plots", 
    #ylabel = "Calories", 
    rot = 45,
    subplots = True, 
    figsize = (20, 7),
    layout = (2, 2)
);

# %%
#Visualization overview

#for duration
m_cal.groupby("Duration").mean().plot(
    kind = "pie",
    title = "Plots", 
    #ylabel = "Calories", 
    #rot = 45,
    subplots = True, 
    figsize = (20, 7),
    #layout = (2, 2)
);                                                          # ;to remove result info

# %% [markdown]
# #### Project: Pandas challenge
# ##### Description - In this task, students will perform an analysis on the world_population dataset using Pandas.

# %%
##1. Import the necessary library
import pandas as pd

##2. import world_population.csv file
m_WP = pd.read_csv(r"D:\2025\UTIVA Projects\Data Science_Python\python-for-data-science-dataset\python-for-data-science-course-main\world_population.csv")
m_WP. head()          #or: m_WP. sample() #for random rows
#to display floats in 2 decimal places
pd.set_option("display.float_format", lambda x: "%.2f" % x)

##3. Using groupBy, find the average '1970 Population', '1980 Population', '1990 Population', '2000 Population',
                                    # '2010 Population', '2015 Population', '2020 Population', '2022 Population' per continent.

#groupby 'continent' and Include desired field to groupby - by listing the column names
#and average
m_WPAv = m_WP.groupby("Continent")[["1970 Population", 
                                    "1980 Population", 
                                    "1990 Population", 
                                    "2000 Population", 
                                    "2010 Population",
                                    "2015 Population", 
                                    "2020 Population", 
                                    "2022 Population"]]. mean()
m_WPAv.head()

##4. Sort the result by '2022 Population' in descending order and Transpose your results
m_WPAvST = m_WPAv.sort_values(by = "2022 Population", ascending = False).T
m_WPAvST.head()

##5. Generate a line plot of the transpose such that the plot shows the average population per year for each continent.
#Visualization

#for duration
m_WPAvST.plot(
    kind = "line",
    title = "Average Population for each continent per census year", 
    #ylabel = "Calories", 
    rot = 45, 
    figsize = (20, 7),
); 

print("Well done! Dami")
# Out:
# Well done! Dami

# %%
#alternative Plot

#m_WPAvST.plot(
#    kind = "line",
#    title = "Plots", 
    #ylabel = "Calories", 
#    rot = 45,
#    subplots = True, 
#    figsize = (20, 7),
#);
